# %%
# !conda install --yes --name JupyterSystemEnv --channel r r-essentials=1.7
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.4.10
#   latest version: 4.5.11
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/ec2-user/anaconda3/envs/JupyterSystemEnv
#
#   added / updated specs:
#     - r-essentials=1.7
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     gcc_impl_linux-64-7.2.0    |       habb00fd_3        72.4 MB
#     r-curl-3.1                 |   r343h086d26f_0         384 KB  r
#     r-utf8-1.1.2               |   r343h086d26f_0         136 KB  r
#     r-xts-0.10_1               |   r343h4829c52_0         689 KB  r
#     r-quantmod-0.4_12          |   r343h889e2dd_0         509 KB  r
#     r-survival-2.41_3          |   r343h086d26f_0         5.1 MB  r
# ...
